# %%
import xarray as xr
import numpy as np
import gc

# %%
a = xr.open_dataset("/Odyssey/public/glorys/reanalysis/glorys12_2010_2019_daily_sla_8th_double.nc").chunk(365)

# %%
def getNorm(input_ds : xr.Dataset) -> list[float] :
    chunked = input_ds.chunk(365)
    
    n = chunked.count()
    sum = chunked.sum(skipna=True)\
        
        
    mu = (sum / n).load()
    var = ((chunked - mu)**2).sum(skipna=True) / n
    sigma = var.load()**0.5
    
    out_list = [mu, sigma]
    
    del n, sum, mu, var, sigma
    gc.collect
    
    return out_list

# %%
print(getNorm(a))
# Out:
# [<xarray.Dataset> Size: 8B
# Dimensions:  ()
# Data variables:
#     sla      float64 8B -9.009e-21, <xarray.Dataset> Size: 8B
# Dimensions:  ()
# Data variables:
#     sla      float64 8B 0.04394]

# %%
print(a.sel(time = slice("2012-01-01", "2012-12-31")).sla.min().compute())
print(a.sel(time = slice("2012-01-01", "2012-12-31")).sla.max().compute())
# Out:
# <xarray.DataArray 'sla' ()> Size: 8B
# array(-1.23398886)
# <xarray.DataArray 'sla' ()> Size: 8B
# array(1.25941028)

# %%
a.std().compute()
# Out:
# <xarray.Dataset> Size: 8B
# Dimensions:  ()
# Data variables:
#     sla      float64 8B 0.04394

# %%
b = a.sla.sel(time = slice("2010-01-01", "2018-12-31")).mean().values.item()
c = a.sla.sel(time = slice("2010-01-01", "2018-12-31")).std().values.item()
d = a.sla.sel(time = slice("2019-01-01", "2019-12-31")).mean().values.item()
e = a.sla.sel(time = slice("2019-01-01", "2019-12-31")).std().values.item()

print(f"Norme 2010-2018 : {b} +/- {c}")
print(f"Norme 2019 : {d} +/- {e}")
# Out:
# Norme 2010-2018 : -2.073333794954459e-20 +/- 0.043911573662524066
# Norme 2019 : -2.1350199874681869e-19 +/- 0.04423288043912259

# %%
aa = xr.open_dataset("/Odyssey/public/altimetry_traces/2010_2023/gridded/validation-filtered-2021-0.25deg.nc").chunk(365)

# %%
aa
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:    (time: 365, latitude: 648, longitude: 1440)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 2021-01-01 2021-01-02 ... 2021-12-31
#   * latitude   (latitude) float64 5kB -80.0 -79.75 -79.5 ... 81.25 81.5 81.75
#   * longitude  (longitude) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
# Data variables:
#     ref        (time, latitude, longitude) float64 3GB dask.array<chunksize=(365, 365, 365), meta=np.ndarray>
#     obs        (time, latitude, longitude) float64 3GB dask.array<chunksize=(365, 365, 365), meta=np.ndarray>

# %%
bb = aa.obs.sel(time = slice("2021-01-01", "2021-12-31")).mean().values.item()
cc = aa.obs.sel(time = slice("2021-01-01", "2021-12-31")).std().values.item()

# %%
print(f"Norme 2021 : {bb} +/- {cc}")
# Out:
# Norme 2021 : 0.08624135039425922 +/- 0.10271981565181278
